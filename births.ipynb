# %% [markdown]
# # Nacimientos

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.13.2'

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib as mpl
mpl.__version__
# Out:
# '3.9.2'

# %%
url = "https://raw.githubusercontent.com/jakevdp/data-CDCbirths/master/births.csv"
births = pd.read_csv(url)
type(births)
# Out:
# pandas.core.frame.DataFrame

# %%
births.head()
# Out:
#    year  month  day gender  births
# 0  1969      1  1.0      F    4046
# 1  1969      1  1.0      M    4440
# 2  1969      1  2.0      F    4454
# 3  1969      1  2.0      M    4548
# 4  1969      1  3.0      F    4548

# %%
births['decade'] = 10 * (births['year'] // 10)
births.pivot_table('births', index='decade', columns='gender', aggfunc='sum')
# Out:
# gender         F         M
# decade
# 1960     1753634   1846572
# 1970    16263075  17121550
# 1980    18310351  19243452
# 1990    19479454  20420553
# 2000    18229309  19106428

# %%
sns.set() # use Seaborn styles
births.pivot_table('births', index='year', columns='gender', aggfunc='sum').plot() 
plt.ylabel('total births per year');

# %%
births.pivot_table('births', index='day', columns='decade', aggfunc='mean').plot() 
plt.gca().set_xticklabels(['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']) 
plt.ylabel('mean births by day');
# Out:
# C:\Temp\ipykernel_30284\1499652148.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_xticklabels(['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun'])
