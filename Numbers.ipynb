# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(10, 10, figsize=(8, 8),
                         subplot_kw={'xticks':[], 'yticks':[]},
                         gridspec_kw=dict(hspace=0.1, wspace=0.1))

for i, ax in enumerate(axes.flat):
    ax.imshow(digits.images[i], cmap='binary', interpolation='nearest')
    ax.text(0.05, 0.05, str(digits.target[i]),
        transform=ax.transAxes, color='green')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       1 fig, axes = plt.subplots(10, 10, figsize=(8, 8),
#       2                          subplot_kw={'xticks':[], 'yticks':[]},
#       3                          gridspec_kw=dict(hspace=0.1, wspace=0.1))
#       5 for i, ax in enumerate(axes.flat):
# ----> 6     ax.imshow(digits.images[i], cmap='binary', interpolation='nearest')
#       7     ax.text(0.05, 0.05, str(digits.target[i]),
#       8         transform=ax.transAxes, color='green')
#
# NameError: name 'digits' is not defined
